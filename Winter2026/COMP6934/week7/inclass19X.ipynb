# %% [markdown]
# # COMP 6934 Winter 2026 In class Work 19X
#
# Guidelines per Tamara Munzner chapter 6.

# %% [markdown]
# ### Problem Set 19
#
#
# Rules of Thumb from Munzner's text.
#
# Modification of problem set 12.
#
# Consider the 3D line plot below, modified from problem 12.
#
# Suppose that the purpose of the plot is to compare the temperature range (low to high) at various locations.

# %%
import pandas as pd

# read the csv data into a dataframe
df = pd.read_csv('../datasets/jash312/NL_weather.csv')
df = df[df['Station Name'].str.contains("ST. JOHN'S INTL")]
df = df[df['Year'] == 2020]
df = df[['Station Name', 'Date/Time', 'Month', 'Max Temp (C)', 'Min Temp (C)']]
aggregated = df.groupby(by='Month').agg(
    {'Station Name': 'first', 'Max Temp (C)': 'max', 'Min Temp (C)': 'min'}).reset_index()
# Out:
# /var/folders/tl/52w5zxkd1zl65mr95qllj_3h0000gn/T/ipykernel_58868/21188022.py:4: DtypeWarning: Columns (0: Climate ID, 1: Total Rain Flag, 2: Total Snow Flag, 3: Snow on Grnd Flag, 4: Spd of Max Gust (km/h)) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../datasets/jash312/NL_weather.csv')

# %%
# read the csv data into a dataframe
df = pd.read_csv('../datasets/jash312/ON_weather.csv')
df = df[df['Station Name'].str.contains("TORONTO INTL")]
df = df[df['Year'] == 2020]
df = df[['Station Name', 'Date/Time', 'Month', 'Max Temp (C)', 'Min Temp (C)']]
dfagg = df.groupby(by='Month').agg(
    {'Station Name': 'first', 'Max Temp (C)': 'max', 'Min Temp (C)': 'min'}).reset_index()
aggregated = pd.concat([aggregated, dfagg])
# Out:
# /var/folders/tl/52w5zxkd1zl65mr95qllj_3h0000gn/T/ipykernel_58868/4097108065.py:2: DtypeWarning: Columns (0: Climate ID) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../datasets/jash312/ON_weather.csv')

# %%
# read the csv data into a dataframe
df = pd.read_csv('../datasets/jash312/BC_weather.csv')
df = df[df['Station Name'].str.contains("VANCOUVER INTL")]
df = df[df['Year'] == 2020]
df = df[['Station Name', 'Date/Time', 'Month', 'Max Temp (C)', 'Min Temp (C)']]
dfagg = df.groupby(by='Month').agg(
    {'Station Name': 'first', 'Max Temp (C)': 'max', 'Min Temp (C)': 'min'}).reset_index()
aggregated = pd.concat([aggregated, dfagg])
# Out:
# /var/folders/tl/52w5zxkd1zl65mr95qllj_3h0000gn/T/ipykernel_58868/1211074278.py:2: DtypeWarning: Columns (0: Climate ID, 1: Spd of Max Gust (km/h)) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../datasets/jash312/BC_weather.csv')

# %%
import plotly.express as px
fig = px.line_3d(aggregated, x="Month", y="Min Temp (C)", z="Max Temp (C)",
                 width=900, height=600,
                 line_group='Station Name',
                 color='Station Name')
fig.show()

# %% [markdown]
# #### Problem 19
#
# Describe and justify three reasons this is a poor choice of visualizaition.  At least two of your reasons should involve "rules of thumb" from Munzner chapter 6. You may use alternative design suggestions to support your critiaue.

# %% [markdown]
# * **No Unjustified 3D**
#
#   3D introduces blockage, perspective distortion, and foreshortening, all of which reduce accuracy of perception. In this 3D plot, it may be difficult to understand what is going on here and gauge the actual change of time (here, months). 2D is almost always more readable.
# * **Eyes beat memory**
#
#   Working memory is severely limited. Spatial proximity allows preattentive, parallel comparison. Side by side views of the above plot is better than forcing the audience to learn the skill of correctly rotating, paning and zooming to be able to (1) view the plots correctly (2) understand the view they are looking at and (3) maintain the view in their working memory to compare.
#
# * **Avoid overplotting**

# %% [markdown]
# # Attributions
#
# Be sure to add your own sources or indicate you have none to add.  Sources can be web sites, text materials, and so on. They do not have to be hyperlinks. Other people are also sources, but they are not allowed for in class credit problems.
#
# | Source | What is it | How used |
# |--|--|--|
# | <https://www.kaggle.com/datasets/jash312/canada-daily-weather-data-from-2018-to-2023> | data sets | taken directly as csv files  |
# | T. Munzner book https://www.cs.ubc.ca/~tmm/vadbook/| rules of thumb | chapter 6 |
