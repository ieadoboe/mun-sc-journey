# %% [markdown]
# ## COMP 6934 Winter 2026 In class Work 15
#
# Methodology per Tamara Munzner.

# %% [markdown]
# ### Problem Set 15
#
# Extension of problem 14.
#
# Marks and channels related to of Munzner's approach.
#
# We'll be using the taxis.csv data set for this problem set.
#
# Note that there are published analyses and notebooks on kaggle covering this dataset. You can look on kaggle if you need more information on the semantics and structure of this data.

# %% [markdown]
# ##### Problem 15.1 - What -
#
# Perform a - *what* - analysis on the dataset. This include determining the Data and Dataset Types, and the Attribute types for each attribute, and any other relevant charateristics from Munzner's  *what* methodology.
#
# You can duplicate your solution in problem 14.1

# %% [markdown]
# #### Problem 15.2 - Why -
#
# To produce { action, target } pairs under Munzner's *why* methodology, you need some questions or objectives in mind; you also need a basic understanding of what the data values mean (semantics).
#
# Which action/target pairs appropriate to each of the following questions/goals:
# * What factors have the most influence on tips?
# * Which factors have the same or similar influence on tips?
#
# Make clear which action/target pairs go with each question/goal.
#
# Provide an interpretation of the questions if needed to motivate each action, target choice.
#
# Note the question has changed from problem 14.2.

# %% [markdown]
# #### Problem 15.3 - How - (but only marks and channels)
#
# We are going to try to complete the design with only partial coverage of Munzner's *HOW* step.
#
# Pick one of the action/target pairs identified in 15.2, and create a plot (in seaborn, plotly, etc.) that you think corresponds to that action/target pair.
#
# Identify the marks and channels used.
#
# You should be illustrating at least three different channels, so add additional plots as necessary until you have at least three different channels illustrated and identified.

# %% [markdown]
# # Attributions
#
# Be sure to add your own sources or indicate you have none to add.  Sources can be web sites, text materials, and so on. They do not have to be hyperlinks. Other people are also sources, but they are not allowed for in class credit problems.
#
# | Source | What is it | How used |
# |--|--|--|
# | https://github.com/mwaskom/seaborn-data Seaborn data samples | data sets | taken directly as csv files  |
# | T. Munzner book https://www.cs.ubc.ca/~tmm/vadbook/| methodology for analysis and design | design choice methods |
