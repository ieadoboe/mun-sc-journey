# %% [markdown]
# # COMP 6934 Winter 2026 In class Work 20
#
# Symbol map from choropleth.

# %% [markdown]
# ### Problem Set 20
#
# Modify the Canadain choropleth from note set 20. Make sure the code for your visualizations is readable in the notebook.
#
# Additional data will be needed from the modified weather data set weather.zip (jash312i)

# %% [markdown]
# #### Problem 20.1
#
# Remove the shape colors for provinces. Change the markers for the capital cities to circles. Size the area of the circle porportional to the population of the capital cities. Add the national capital (Ottawa) to the plot.

# %% [markdown]
# #### Problem 20.2
#
# Color the markers for the capital cities according to the temperature for a particular day. You can pick the day. Make sure to label the design with the colors scale from blue (cold) to red (hot).

# %% [markdown]
# #### Problem 20.3
#
# Move the coloring from the city markers to the choropleth shapes. Answer the questions: what would Munzner's ideas about marks and channels say about whether this change in design is an improvement?

# %% [markdown]
# # Attributions
#
# Be sure to add your own sources or indicate you have none to add.  Sources can be web sites, text materials, and so on. They do not have to be hyperlinks. Other people are also sources, but they are not allowed for in class credit problems.
#
# | Source | What is it | How used |
# |--|--|--|
# | <https://www.kaggle.com/datasets/jash312/canada-daily-weather-data-from-2018-to-2023> | data sets | used data from csv files after cleaning  |
# | https://simplemaps.com/data/canada-cities | data for canadian cities | |
# | ~~https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1710000901~~ | ~~Canadian quarterly population estimates~~ ||
# | https://github.com/plotly/plotly.py/blob/main/doc/python/choropleth-maps.md | plotly chloropleth maps | code examples |
# | https://data.opendatasoft.com/explore/dataset/georef-canada-province%40public/export/?disjunctive.prov_name_en&flg=en-us | geojson for Canadian provinces |
# | https://plotly.com/python/scatter-plots-on-maps/ | plotly scattergeo traces | code examples |
# | https://plotly.com/python/reference/scattergeo/#scattergeo | plotly scatter-geo reference | parameter definitions |
