# %% [markdown]
# ## Project Proposal COMP 6934 W26
#
# Your term project will be visualization designs for a selected dataset.
#
# The final project will include
#
# * A minimum of three visualizations. One (or more) of the visualizations should demonstrate an original design incorporating animation or interaction in a creative manner.
# * A complete analysis in the manner of assignment 2 will be expected, including:
#     * introduction to the data sources and data set
#     * data analysis incorporating a *what* methodology
#     * purposes and goals of the visualization project, driven by client questions and needs, and incorporating Munzner-style *why* methods
# * A section for each visual design used, including code, discussion of the design motivation for each visual design, incorporating idioms, *how* analysis, and sources of inspiration such as existing designs or gallery entries.
# * A conclusion discussing the success of the visualizations and suggestions for improvement.

# %% [markdown]
# # Proposal Instructions
#
# For the project proposal, you must select a dataset for your final project and provide an initial description of how you will address the dataset in your project.
#
# **Selection of the dataset** is on a competitive, first-come, basis, each student should have a different dataset to work with. Be the first to **claim your selection** at the [selection web site](https://www.cs.mun.ca/~brown/6934/signupProject/projselect.php) https://www.cs.mun.ca/~brown/6934/signupProject/projselect.php
# * For most projects, more than one data file will be appropriate; you may want to obtain data from differenct sources in order to construct reasonable goals for the project and for the topic under study. You should list the most important dataset, or you may list multiple datasets in the selection.
# * Approval of your selection will be based on the qualities of the data set
#     * enough data points to provide interesting design tasks. Anything under 2000 data points would be considered too small. Smaller data sets with complex data items (such as geometries and/or links) may also be acceptable.
#     * different types of data and/or attributes allow a variety of possible visuals
#     * real world interesting subject matter (no fake or generated data sets)
#
# **Work with a client** if you can. I have recruited a few faculty members who have data visualization problems to work on. I will post these as possible dataset choices. You may recruit your own *reliable* client (such as a faculty member) to work with.  I will provide an information sheet for them and some basic questions for you to ask before making final commitment to working with your client.
#
# **Work without a client** if you want. You must find your own dataset to work with and also act as the client by imagining appropriate goals and objectives. I will also post some suggestions for finding a dataset selection without a client.
#
# Include these items in your proposal submission.
# * Introduction to the dataset selection and all data files chosen for the project; also introduce the client
#     * If you are not working without an actual client, describe the type of individual or organization that would be interested in your project. You will want to frame your objectives and results in terms of their utility for this imanginary client.
# * A preliminary analysis of the data set apply *what* methods
# * A minimum of three questions regarding the dataset, expressing your client's goals and objectives, suitable for a Munzner style *why* analysis.
# * Any initial ideas for visualizations, including visuals you do not currently know how to code (you can simply sketch or mock up the images of the visualization). Do not limit your ideas to code solutions you are already familiar with.
#     * Explain what each visual accomplishes in terms of the project goals
#     * Submit at least three visual designs for feedback. They do not have to be coded.
#
# Optionally include any other preliminary ideas for other parts of the final submission. These will not be graded for marks, but you may get some good guidance and feedback.

# %% [markdown]
# # Attributions
#
# Be sure to add your own sources or indicate you have none to add.  Sources can be web sites, text materials, and so on. They do not have to be hyperlinks. Other people are also sources.
#
# | Source | What is it | How used |
# |--|--|--|
# | source goes here | information, analysis ideas, data, code, plots are examples.   | did you copy content, use suggestions, or follow a strategy, and where in your submission does it appear

# %% [markdown]
# # Evaluation
#
# ### Distribution of points for evaluation:
#
# Include these items in your proposal submission.
# * [5 points] Introduction to the dataset selection and all data files chosen for the project; also introduce the client
#     * If you are not working without an actual client, describe the type of individual or organization that would be interested in your project. You will want to frame your objectives and results in terms of their utility for this imaginary client.
# * [15 points] A preliminary analysis of the data set apply *what* methods
#   * [5] sufficient data set types and attribute types to justify a visualization project with new interesting visualizations
#   * [5] complete data and data set *what* analysis per Munzner
#   * [5] sufficient data in total to make for interesting and informative visualization possible
# * [30 points] A minimum of three questions regarding the dataset, expressing your client's goals and objectives, suitable for a Munzner style *why* analysis.
#     * [10 each for 3 questions]
#         * [5] question helps frame the project goals
#         * [5] each question suggests a different way of looking at the data
#             * questions that are too specific leave no design room. The question should not create the design.
#             * some vague questions are good for design scope, but more than one vague question will probably add no design scope to the project. A mixture of general and specific questions is recommended
#             * some more specific questions (directed more a specific attributes or effects) will produce new targets and new ideas for the design
#             * you may provide action/target pairs according to Munzner's *why* methodology (they will be required on the final project)
# * [48 points] Any initial ideas for visualizations, including visuals you do not currently know how to code (you can simply sketch or mock up the images of the visualization). Do not limit your ideas to code solutions you are already familiar with.
#     * Explain what each visual accomplishes in terms of the project goals
#     * Submit at least three visual designs for feedback. They do not have to be coded.
#     * [16 each x 3 designs]
#         * [4] design relation to project goals via 3 questions is made clear
#         * [4] design goes further than simple copy of standard visualization idioms (bar chart, line chart, scatter plot..) demonstrating creativity of design. Simple designs are useful vis (simple is often better), but add others to get better design credit and show creativity.
#         * [4] multiple dimension of data set addressed with use of marks and channels
#         * [4] multiple methods of *how* methodology reflected in designs. You may specifically indicate the *how* elements that influence the design, but it is not required at this stage.
# * [2] Attributions
# Optionally include any other preliminary ideas for other parts of the final submission. These will not be graded for marks, but you may get some good guidance and feedback.
# * [100] Total
