# %% [markdown]
# ## Assignment 2 COMP 6934 W26 Marking Scheme
#
# Let's look at three data sources relating to the 2025 Canadian General Election:
#
# * Riding level voting for each Candidate
#     * from Elections Canada
#     *  <https://www.elections.ca/content.aspx?section=res&dir=rep/off/45gedata&document=summary&lang=e>
#         *  specifically table 12 shows the candidates and votes
#             * the party affiliation is unfortunately mashed in with the candidate's name
# * Sources of income by province
#     * https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=3610071101
#     * In download options, choose to download the entire table in CSV format
#     * You will get historical data going back to 1997, but you can restrict the assignment to the most recent data if you want.
# * Current representation in the Canadian House of Commons
#     * Should match the winners in the General Election, except for a few by-elections since the general election
#     * <https://www.ourcommons.ca/Members/en/search> includes pictures
#     * There is a link to a csv without pictures <https://www.ourcommons.ca/Members/en/search/csv>
#         * Political party has its own column, unlike the riding voting file
#         * Matching up records with the voting file may require some data adjustments

# %% [markdown]
# # Notebook sections with evaluation points
#
# Create two visualizations to explore the relationship between provincial economy and voting patterns in 2025.
#
# Use a methodology based on Munzner's approach. Your notebook/submission should have the following sections:
#
# * Overview/Abstract of your notebook and solution, what was studied and what is shown.
#     * include how to reproduce your results, where your code is not obvious.
# * [6 POINTS] General description of data sets
#     * [2] What is the subject matter of the data collection(s)?
#         * __A simple statement for each data set is sufficient__
#     * [2] What is included in the data, how was it sourced, how was it collected.
#     * [2] Organization/format of the data
# * [10 POINTS] Data details
#     * A *what* analysis of the data
#         * [5] TYPE/ORDERING OF EACH ATTRIBUTE IDENTITFIED
#         * [5] TYPE OF DATASET AND STRUCTURE IDENTIFIED
#     * if you have observations about the data set outside the *what* analysis, be sure to include them.
#         * MARKER'S DISCRETION TO ADJUST FOR ASPECTS MISSED IN WHAT ANALYSIS
# * [10 POINTS] Preliminary exploration
#     * There is often a preliminary exploration of the data set(s) to help you understand what the basic structure and realtionships are present. This usually includes some simple statistics and plots.
# * [32 points] Purpose of visualizations
#     * Perform a *why* analysis of the data set.
#     * Base analysis on two general questions:
#         * "Is there a relationship between a province's economics and its party support?"
#         * "Is there a relationship between Alberta's conservative orientation and its industry, particularly its oil industry, as compared to other provinces?"
#     * You should produce action-target pairs appropriate to these questions, and explain them as necessary.
#         * [16] ACTION-TARGET PAIRS FOR QUESTION 1
#             * [8] CONSIDERED AT THREE LEVELS OF ANALYSIS
#                 * __levels are analyze, search, query__
#             * [8] PAIRS RATIONALLY JUSTIFIED FROM DATA TYPES AND SEMANTICS
#           * [16] ACTION-TARGET PAIRS FOR QUESTION 1
#             * [8] CONSIDERED AT THREE LEVELS OF ANALYSIS
#                 * __levels are analyze, search, query__
#             * [8] PAIRS RATIONALLY JUSTIFIED FROM DATA TYPES AND SEMANTICS
#     * If you have observations about goals or purpose of visuals outside the *why* analysis, be sure to include them.
#         * MARKER'S DISCRETION TO ADJUST FOR ASPECTS MISSED IN WHY ANALYSIS
# * [32 POINTS] Design of visuals
#     * Perform a *how* analysis of the data set.
#         * Justify the choice of idioms and channels based on your what/why analysis
#     * If you have observations about visual design outside the *how* analysis, be sure to include them.
#     * You should reference and attribute sources of inspiration for you visuals - other visuals, galleries, etc, and also explain which elements are your own original ideas in your designs.
#     * [10] IDIOMS AND METHODS FOR DESIGN 1
#         * [2] CONNECTION TO ONE OR MORE WHAT/WHY TARGET PAIRS
#         * [4] IDIOMS SOURCES AND ORIGINALITY INVOLVED IDENTIFIED
#         * [4] HOW METHODS INVOLVED IDENTIFIED
#     * [10] IDIOMS AND METHODS FOR DESIGN 2
#         * [2] CONNECTION TO ONE OR MORE WHAT/WHY TARGET PAIRS
#         * [4] IDIOMS SOURCES AND ORIGINALITY INVOLVED IDENTIFIED
#         * [4] HOW METHODS INVOLVED IDENTIFIED
#
#     * [12] Most of your code cells will be in this section, and some code cells in data details could also make sense.
#         * [6] CODE EFFORT DEMONSTRATED TO PRODUCE PLOTS MORE THAN SIMPLE COPY/PASTE. FIGURE FOLLOW ANALYSIS, NOT STUDENT CAPABILITIES OR LIMITATIONS
#             * __a simple copy of a well know idiom with nothing further should fail this part of the scheme__
#         * [6] RESULTING FIGURES REFLECT ADEQUATE WHAT/WHY/HOW ANALYSIS AND DESIGN. FIGURE FOLLOW ANALYSIS, NOT STUDENT CAPABILITIES
#             * __the design should follow from the analysis provided for "why" and "how"__
# * [10 POINTS] Conclusion
#     * Discuss how successful your visualizations are, and what improvements could be investigated.
#     * [10] DISCUSSION SHOULD MATCH TARGET OBJECTIVES SUCCESS AND ORIGINAL QUESTIONS ALSO DISCUSS DESIGN IMPROVEMENT TO BETTER USE OF MARKS AND CHANNELS WITH SPECIFIC DESIGN IDEAS
#         * __[6 points] the student should take both visuals, discuss them in terms of success in addressing the action/target pairs and the original questions. The pairs and questions should be explicitly mentioned__
#         * __[4 points] the student should make suggestions for alternative or improved designs__
#
# __Reject a submission without an attributions section__
#
# * [100 points] Conclusion

# %% [markdown]
# # Attributions
#
# Be sure to add your own sources as well as those provided.  Sources can be web sites, text materials, and so on. They do not have to be hyperlinks. Other people are also sources, but they should not be solving your assignment for you.
#
# | Source | What is it | How used |
# |--|--|--|
# | source goes here | information, analysis ideas, data, code, plots are examples.   | did you copy content, use suggestions, or follow a strategy, and where in your submission does it appear
